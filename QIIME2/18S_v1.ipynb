# %%
#import the qiime2 python module to allow for inline visualizations

import qiime2 as q2

# %%
#which version of qiime2 and python are we using?

# !qiime info
# Out:
# System versions
# Python version: 3.6.10
# QIIME 2 release: 2020.6
# QIIME 2 version: 2020.6.0
# q2cli version: 2020.6.0
#
# Installed plugins
# alignment: 2020.6.0
# composition: 2020.6.0
# cutadapt: 2020.6.0
# dada2: 2020.6.0
# deblur: 2020.6.0
# demux: 2020.6.0
# diversity: 2020.6.0
# diversity-lib: 2020.6.0
# emperor: 2020.6.0
# feature-classifier: 2020.6.0
# feature-table: 2020.6.0
# fragment-insertion: 2020.6.0
# gneiss: 2020.6.0
# longitudinal: 2020.6.0
# metadata: 2020.6.0
# phylogeny: 2020.6.0
# quality-control: 2020.6.0
# quality-filter: 2020.6.0
# sample-classifier: 2020.6.0
# taxa: 2020.6.0
# types: 2020.6.0
# vsearch: 2020.6.0
#
# Application config directory
# /Users/stephaniematthews/miniconda3/envs/qiime2-2020.6/var/q2cli
#
# Getting help
# To get help with QIIME 2, visit https://qiime2.org

# %% [markdown]
# First, import the paired forward and reverse sequences with a manifest file. Manifest prepared by listing all files in bash and formatting in Excel.

# %%
#Import the fastq files into a QIIME2 artifact 

# !qiime tools import \
  --type 'SampleData[PairedEndSequencesWithQuality]' \
  --input-path zhan_manifest_run1_grid.csv \
  --output-path 18S-paired-end-demux_r1.qza \
  --input-format PairedEndFastqManifestPhred33
# Out:
# Imported zhan_manifest_run1_grid.csv as PairedEndFastqManifestPhred33 to 18S-paired-end-demux_r1.qza

# %%
#Import the fastq files into a QIIME2 artifact 

# !qiime tools import \
  --type 'SampleData[PairedEndSequencesWithQuality]' \
  --input-path zhan_manifest_run2_v1.csv \
  --output-path 18S-paired-end-demux_r2.qza \
  --input-format PairedEndFastqManifestPhred33
# Out:
# Imported zhan_manifest_run2_v1.csv as PairedEndFastqManifestPhred33 to 18S-paired-end-demux_r2.qza

# %% [markdown]
# Trim reverse primers
# See: https://docs.qiime2.org/2020.6/plugins/available/cutadapt/trim-paired/
# default is to match IUPAC wildcards ( --p-match-adapter-wildcards T )
# - these should be the F/R marker primers
# - cannot handle inosine bases; using N instead
# - f primer/ r primer
# - or could just trim off length of primer ? but this provides a test of primer accuracy

# %%
# !qiime cutadapt trim-paired \
    --i-demultiplexed-sequences 18S-paired-end-demux_r1.qza \
    --p-front-f '^AGGGCAAKYCTGGTGCCAGC' \
    --p-front-r '^GRCGGTATCTRATCGYCTT' \
    --o-trimmed-sequences 18S-demux-pairedend-trimmed1.qza \
    --verbose
# !qiime cutadapt trim-paired \
    --i-demultiplexed-sequences 18S-paired-end-demux_r2.qza \
    --p-front-f '^AGGGCAAKYCTGGTGCCAGC' \
    --p-front-r '^GRCGGTATCTRATCGYCTT' \
    --o-trimmed-sequences 18S-demux-pairedend-trimmed2.qza \
    --verbose
# Out:
# Running external command line application. This may print messages to stdout and/or stderr.
# The commands to be run are below. These commands cannot be manually re-run as they will depend on temporary files that no longer exist.
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S124_0_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S124_1_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S124_0_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S124_1_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S124_0_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S124_1_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S124_0_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S124_1_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        67,912 reads  @     64.5 µs/read;   0.93 M reads/minute
# Finished in 4.39 s (65 us/read; 0.93 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             67,912
#   Read 1 with adapter:                  67,897 (100.0%)
#   Read 2 with adapter:                  67,576 (99.5%)
# Pairs written (passing filters):        67,912 (100.0%)
#
# Total basepairs processed:    40,065,443 bp
#   Read 1:    20,033,305 bp
#   Read 2:    20,032,138 bp
# Total written (filtered):     37,426,257 bp (93.4%)
#   Read 1:    18,676,745 bp
#   Read 2:    18,749,512 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 67897 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	68	0.0	1	0 0 68
# 19	1429	0.0	1	0 1381 48
# 20	66252	0.0	2	64654 1581 17
# 21	111	0.0	2	0 105 6
# 22	37	0.0	2	0 0 37
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 67576 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1447	0.0	1	0 1447
# 19	66000	0.0	1	64304 1696
# 20	129	0.0	1	0 129
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S125_2_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S125_3_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S125_2_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S125_3_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S125_2_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S125_3_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S125_2_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S125_3_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        49,744 reads  @     66.8 µs/read;   0.90 M reads/minute
# Finished in 3.33 s (67 us/read; 0.90 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             49,744
#   Read 1 with adapter:                  49,730 (100.0%)
#   Read 2 with adapter:                  49,443 (99.4%)
# Pairs written (passing filters):        49,744 (100.0%)
#
# Total basepairs processed:    29,347,422 bp
#   Read 1:    14,673,323 bp
#   Read 2:    14,674,099 bp
# Total written (filtered):     27,415,283 bp (93.4%)
#   Read 1:    13,679,784 bp
#   Read 2:    13,735,499 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 49730 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	47	0.0	1	0 0 47
# 19	1083	0.0	1	0 1057 26
# 20	48509	0.0	2	47260 1233 16
# 21	66	0.0	2	0 63 3
# 22	25	0.0	2	0 0 25
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 49443 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	915	0.0	1	0 915
# 19	48430	0.0	1	46983 1447
# 20	98	0.0	1	0 98
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S126_4_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S126_5_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S126_4_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S126_5_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S126_4_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S126_5_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S126_4_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S126_5_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        54,118 reads  @     70.3 µs/read;   0.85 M reads/minute
# Finished in 3.81 s (70 us/read; 0.85 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             54,118
#   Read 1 with adapter:                  54,106 (100.0%)
#   Read 2 with adapter:                  53,606 (99.1%)
# Pairs written (passing filters):        54,118 (100.0%)
#
# Total basepairs processed:    31,927,906 bp
#   Read 1:    15,964,212 bp
#   Read 2:    15,963,694 bp
# Total written (filtered):     29,829,258 bp (93.4%)
#   Read 1:    14,883,157 bp
#   Read 2:    14,946,101 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 54106 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	43	0.0	1	0 0 43
# 19	1098	0.0	1	0 1061 37
# 20	52870	0.0	2	51547 1297 26
# 21	71	0.0	2	0 70 1
# 22	24	0.0	2	0 0 24
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 53606 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1020	0.0	1	0 1020
# 19	52487	0.0	1	50768 1719
# 20	99	0.0	1	0 99
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S127_6_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S127_7_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S127_6_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S127_7_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S127_6_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S127_7_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S127_6_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S127_7_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        60,020 reads  @     72.7 µs/read;   0.83 M reads/minute
# Finished in 4.37 s (73 us/read; 0.82 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             60,020
#   Read 1 with adapter:                  60,005 (100.0%)
#   Read 2 with adapter:                  59,765 (99.6%)
# Pairs written (passing filters):        60,020 (100.0%)
#
# Total basepairs processed:    35,410,803 bp
#   Read 1:    17,704,936 bp
#   Read 2:    17,705,867 bp
# Total written (filtered):     33,077,353 bp (93.4%)
#   Read 1:    16,506,054 bp
#   Read 2:    16,571,299 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 60005 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	54	0.0	1	0 0 54
# 19	1246	0.0	1	0 1204 42
# 20	58590	0.0	2	57053 1522 15
# 21	94	0.0	2	0 94
# 22	21	0.0	2	0 0 21
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 59765 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1095	0.0	1	0 1095
# 19	58542	0.0	1	56981 1561
# 20	128	0.0	1	0 128
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S128_8_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S128_9_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S128_8_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S128_9_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S128_8_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S128_9_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S128_8_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S128_9_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        51,242 reads  @     71.0 µs/read;   0.84 M reads/minute
# Finished in 3.64 s (71 us/read; 0.84 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             51,242
#   Read 1 with adapter:                  51,232 (100.0%)
#   Read 2 with adapter:                  50,999 (99.5%)
# Pairs written (passing filters):        51,242 (100.0%)
#
# Total basepairs processed:    30,231,296 bp
#   Read 1:    15,116,131 bp
#   Read 2:    15,115,165 bp
# Total written (filtered):     28,239,587 bp (93.4%)
#   Read 1:    14,092,615 bp
#   Read 2:    14,146,972 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 51232 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	49	0.0	1	0 0 49
# 19	1145	0.0	1	0 1118 27
# 20	49934	0.0	2	48735 1176 23
# 21	89	0.0	2	0 85 4
# 22	15	0.0	2	0 0 15
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 50999 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	881	0.0	1	0 881
# 19	50025	0.0	1	48672 1353
# 20	93	0.0	1	0 93
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S129_10_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S129_11_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S129_10_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S129_11_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S129_10_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S129_11_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S129_10_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S129_11_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        48,537 reads  @     71.7 µs/read;   0.84 M reads/minute
# Finished in 3.48 s (72 us/read; 0.84 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             48,537
#   Read 1 with adapter:                  48,523 (100.0%)
#   Read 2 with adapter:                  48,218 (99.3%)
# Pairs written (passing filters):        48,537 (100.0%)
#
# Total basepairs processed:    28,623,448 bp
#   Read 1:    14,317,401 bp
#   Read 2:    14,306,047 bp
# Total written (filtered):     26,738,717 bp (93.4%)
#   Read 1:    13,347,908 bp
#   Read 2:    13,390,809 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 48523 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	58	0.0	1	0 0 58
# 19	978	0.0	1	0 950 28
# 20	47387	0.0	2	46139 1234 14
# 21	73	0.0	2	0 73
# 22	27	0.0	2	0 0 27
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 48218 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	989	0.0	1	0 989
# 19	47144	0.0	1	45859 1285
# 20	85	0.0	1	0 85
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S130_12_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S130_13_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S130_12_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S130_13_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S130_12_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S130_13_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S130_12_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S130_13_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        60,486 reads  @     72.0 µs/read;   0.83 M reads/minute
# Finished in 4.36 s (72 us/read; 0.83 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             60,486
#   Read 1 with adapter:                  60,472 (100.0%)
#   Read 2 with adapter:                  60,055 (99.3%)
# Pairs written (passing filters):        60,486 (100.0%)
#
# Total basepairs processed:    35,664,535 bp
#   Read 1:    17,843,224 bp
#   Read 2:    17,821,311 bp
# Total written (filtered):     33,316,132 bp (93.4%)
#   Read 1:    16,634,985 bp
#   Read 2:    16,681,147 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 60472 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	44	0.0	1	0 0 44
# 19	1246	0.0	1	0 1200 46
# 20	59076	0.0	2	57483 1564 29
# 21	79	0.0	2	0 77 2
# 22	27	0.0	2	0 0 27
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 60055 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	973	0.0	1	0 973
# 19	58990	0.0	1	57546 1444
# 20	92	0.0	1	0 92
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S131_14_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S131_15_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S131_14_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S131_15_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S131_14_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S131_15_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S131_14_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S131_15_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:05        69,839 reads  @     73.4 µs/read;   0.82 M reads/minute
# Finished in 5.13 s (73 us/read; 0.82 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             69,839
#   Read 1 with adapter:                  69,830 (100.0%)
#   Read 2 with adapter:                  67,848 (97.1%)
# Pairs written (passing filters):        69,839 (100.0%)
#
# Total basepairs processed:    41,092,988 bp
#   Read 1:    20,601,721 bp
#   Read 2:    20,491,267 bp
# Total written (filtered):     38,409,198 bp (93.5%)
#   Read 1:    19,206,506 bp
#   Read 2:    19,202,692 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 69830 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	50	0.0	1	0 0 50
# 19	1444	0.0	1	0 1385 59
# 20	68208	0.0	2	66447 1737 24
# 21	97	0.0	2	0 96 1
# 22	31	0.0	2	0 0 31
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 67848 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	647	0.0	1	0 647
# 19	67091	0.0	1	65644 1447
# 20	110	0.0	1	0 110
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S132_16_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S132_17_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S132_16_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S132_17_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S132_16_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S132_17_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S132_16_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S132_17_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        68,047 reads  @     65.5 µs/read;   0.92 M reads/minute
# Finished in 4.46 s (66 us/read; 0.92 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             68,047
#   Read 1 with adapter:                  68,033 (100.0%)
#   Read 2 with adapter:                  67,727 (99.5%)
# Pairs written (passing filters):        68,047 (100.0%)
#
# Total basepairs processed:    40,144,011 bp
#   Read 1:    20,073,426 bp
#   Read 2:    20,070,585 bp
# Total written (filtered):     37,498,770 bp (93.4%)
#   Read 1:    18,713,734 bp
#   Read 2:    18,785,036 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 68033 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	43	0.0	1	0 0 43
# 19	1064	0.0	1	0 1041 23
# 20	66783	0.0	2	65001 1755 27
# 21	104	0.0	2	0 103 1
# 22	39	0.0	2	0 0 39
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 67727 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1409	0.0	1	0 1409
# 19	66173	0.0	1	64532 1641
# 20	145	0.0	1	0 145
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S133_18_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S133_19_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S133_18_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S133_19_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S133_18_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S133_19_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S133_18_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S133_19_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        69,695 reads  @     59.3 µs/read;   1.01 M reads/minute
# Finished in 4.14 s (59 us/read; 1.01 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             69,695
#   Read 1 with adapter:                  69,690 (100.0%)
#   Read 2 with adapter:                  69,316 (99.5%)
# Pairs written (passing filters):        69,695 (100.0%)
#
# Total basepairs processed:    41,119,345 bp
#   Read 1:    20,559,999 bp
#   Read 2:    20,559,346 bp
# Total written (filtered):     38,410,807 bp (93.4%)
#   Read 1:    19,167,293 bp
#   Read 2:    19,243,514 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 69690 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	52	0.0	1	0 0 52
# 19	1159	0.0	1	0 1118 41
# 20	68349	0.0	2	66615 1712 22
# 21	91	0.0	2	0 88 3
# 22	39	0.0	2	0 0 39
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 69316 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1282	0.0	1	0 1282
# 19	67924	0.0	1	66152 1772
# 20	110	0.0	1	0 110
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S134_20_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S134_21_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S134_20_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S134_21_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S134_20_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S134_21_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S134_20_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S134_21_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [  8<--------] 00:00:04        80,095 reads  @     59.3 µs/read;   1.01 M reads/minute
# Finished in 4.75 s (59 us/read; 1.01 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             80,095
#   Read 1 with adapter:                  80,079 (100.0%)
#   Read 2 with adapter:                  79,737 (99.6%)
# Pairs written (passing filters):        80,095 (100.0%)
#
# Total basepairs processed:    47,255,407 bp
#   Read 1:    23,627,804 bp
#   Read 2:    23,627,603 bp
# Total written (filtered):     44,141,514 bp (93.4%)
#   Read 1:    22,027,438 bp
#   Read 2:    22,114,076 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 80079 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	52	0.0	1	0 0 52
# 19	1314	0.0	1	0 1288 26
# 20	78553	0.0	2	76498 2026 29
# 21	116	0.0	2	0 115 1
# 22	44	0.0	2	0 0 44
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 79737 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1641	0.0	1	0 1641
# 19	77931	0.0	1	76056 1875
# 20	165	0.0	1	0 165
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S135_22_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S135_23_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S135_22_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S135_23_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S135_22_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S135_23_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S135_22_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S135_23_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [  8<--------] 00:00:04        81,314 reads  @     61.3 µs/read;   0.98 M reads/minute
# Finished in 4.98 s (61 us/read; 0.98 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             81,314
#   Read 1 with adapter:                  81,300 (100.0%)
#   Read 2 with adapter:                  81,008 (99.6%)
# Pairs written (passing filters):        81,314 (100.0%)
#
# Total basepairs processed:    47,974,606 bp
#   Read 1:    23,987,034 bp
#   Read 2:    23,987,572 bp
# Total written (filtered):     44,812,090 bp (93.4%)
#   Read 1:    22,362,356 bp
#   Read 2:    22,449,734 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 81300 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	55	0.0	1	0 0 55
# 19	1418	0.0	1	0 1377 41
# 20	79671	0.0	2	77587 2053 31
# 21	106	0.0	2	0 104 2
# 22	50	0.0	2	0 0 50
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 81008 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1482	0.0	1	0 1482
# 19	79358	0.0	1	77512 1846
# 20	168	0.0	1	0 168
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S136_24_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S136_25_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S136_24_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S136_25_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S136_24_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S136_25_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S136_24_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S136_25_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        46,544 reads  @     65.6 µs/read;   0.91 M reads/minute
# Finished in 3.06 s (66 us/read; 0.91 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             46,544
#   Read 1 with adapter:                  46,532 (100.0%)
#   Read 2 with adapter:                  46,368 (99.6%)
# Pairs written (passing filters):        46,543 (100.0%)
#
# Total basepairs processed:    27,459,035 bp
#   Read 1:    13,729,821 bp
#   Read 2:    13,729,214 bp
# Total written (filtered):     25,648,572 bp (93.4%)
#   Read 1:    12,799,612 bp
#   Read 2:    12,848,960 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 46532 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	31	0.0	1	0 0 31
# 19	765	0.0	1	0 738 27
# 20	45646	0.0	2	44561 1079 6
# 21	59	0.0	2	0 57 2
# 22	31	0.0	2	0 0 31
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 46368 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	821	0.0	1	0 821
# 19	45464	0.0	1	44391 1073
# 20	83	0.0	1	0 83
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S137_26_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S137_27_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S137_26_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S137_27_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S137_26_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S137_27_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S137_26_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S137_27_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        74,550 reads  @     61.9 µs/read;   0.97 M reads/minute
# Finished in 4.61 s (62 us/read; 0.97 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             74,550
#   Read 1 with adapter:                  74,528 (100.0%)
#   Read 2 with adapter:                  74,148 (99.5%)
# Pairs written (passing filters):        74,549 (100.0%)
#
# Total basepairs processed:    43,966,112 bp
#   Read 1:    21,991,857 bp
#   Read 2:    21,974,255 bp
# Total written (filtered):     41,069,114 bp (93.4%)
#   Read 1:    20,502,233 bp
#   Read 2:    20,566,881 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 74528 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	60	0.0	1	0 0 60
# 19	1298	0.0	1	0 1263 35
# 20	73005	0.0	2	71027 1950 28
# 21	123	0.0	2	0 120 3
# 22	42	0.0	2	0 0 42
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 74148 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1567	0.0	1	0 1567
# 19	72452	0.0	1	70694 1758
# 20	129	0.0	1	0 129
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S138_28_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S138_29_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S138_28_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S138_29_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S138_28_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S138_29_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S138_28_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S138_29_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [   8=-------] 00:00:09       146,234 reads  @     62.0 µs/read;   0.97 M reads/minute
# Finished in 9.07 s (62 us/read; 0.97 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:            146,234
#   Read 1 with adapter:                 146,199 (100.0%)
#   Read 2 with adapter:                 145,342 (99.4%)
# Pairs written (passing filters):       146,233 (100.0%)
#
# Total basepairs processed:    86,226,364 bp
#   Read 1:    43,138,552 bp
#   Read 2:    43,087,812 bp
# Total written (filtered):     80,545,108 bp (93.4%)
#   Read 1:    40,216,550 bp
#   Read 2:    40,328,558 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 146199 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	94	0.0	1	0 0 94
# 19	2388	0.0	1	0 2306 82
# 20	143461	0.0	2	139614 3787 60
# 21	189	0.0	2	0 176 13
# 22	67	0.0	2	0 0 67
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 145342 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	2493	0.0	1	0 2493
# 19	142600	0.0	1	139439 3161
# 20	249	0.0	1	0 249
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S139_30_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S139_31_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S139_30_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S139_31_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S139_30_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S139_31_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S139_30_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S139_31_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        53,802 reads  @     64.7 µs/read;   0.93 M reads/minute
# Finished in 3.49 s (65 us/read; 0.93 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             53,802
#   Read 1 with adapter:                  53,786 (100.0%)
#   Read 2 with adapter:                  52,314 (97.2%)
# Pairs written (passing filters):        53,802 (100.0%)
#
# Total basepairs processed:    31,658,865 bp
#   Read 1:    15,870,808 bp
#   Read 2:    15,788,057 bp
# Total written (filtered):     29,590,393 bp (93.5%)
#   Read 1:    14,795,912 bp
#   Read 2:    14,794,481 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 53786 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	44	0.0	1	0 0 44
# 19	890	0.0	1	0 871 19
# 20	52731	0.0	2	51329 1375 27
# 21	88	0.0	2	0 82 6
# 22	33	0.0	2	0 0 33
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 52314 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	465	0.0	1	0 465
# 19	51774	0.0	1	50705 1069
# 20	75	0.0	1	0 75
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S140_32_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S140_33_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S140_32_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S140_33_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S140_32_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S140_33_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S140_32_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S140_33_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:03        64,232 reads  @     59.8 µs/read;   1.00 M reads/minute
# Finished in 3.84 s (60 us/read; 1.00 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             64,232
#   Read 1 with adapter:                  64,216 (100.0%)
#   Read 2 with adapter:                  63,918 (99.5%)
# Pairs written (passing filters):        64,232 (100.0%)
#
# Total basepairs processed:    37,895,298 bp
#   Read 1:    18,947,569 bp
#   Read 2:    18,947,729 bp
# Total written (filtered):     35,398,308 bp (93.4%)
#   Read 1:    17,663,725 bp
#   Read 2:    17,734,583 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 64216 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	26	0.0	1	0 0 26
# 19	600	0.0	1	0 584 16
# 20	63457	0.0	2	61876 1561 20
# 21	90	0.0	2	0 88 2
# 22	43	0.0	2	0 0 43
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 63918 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1434	0.0	1	0 1434
# 19	62346	0.0	1	60605 1741
# 20	138	0.0	1	0 138
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S141_34_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S141_35_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S141_34_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S141_35_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S141_34_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-08292wl3/S141_35_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S141_34_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-ai6v6i0m/de9fa4bb-feda-4d19-afd1-24366884ce72/data/S141_35_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# ...
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S484_226_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S484_227_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S484_226_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S484_227_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8<----------] 00:00:01        15,565 reads  @     66.0 µs/read;   0.91 M reads/minute
# Finished in 1.03 s (66 us/read; 0.91 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             15,565
#   Read 1 with adapter:                  15,549 (99.9%)
#   Read 2 with adapter:                  15,469 (99.4%)
# Pairs written (passing filters):        15,565 (100.0%)
#
# Total basepairs processed:     9,176,152 bp
#   Read 1:     4,591,097 bp
#   Read 2:     4,585,055 bp
# Total written (filtered):      8,571,640 bp (93.4%)
#   Read 1:     4,280,253 bp
#   Read 2:     4,291,387 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 15549 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	11	0.0	1	0 0 11
# 19	149	0.0	1	0 143 6
# 20	15360	0.0	2	14468 868 24
# 21	23	0.0	2	0 23
# 22	6	0.0	2	0 0 6
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 15469 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	270	0.0	1	0 270
# 19	15172	0.0	1	14830 342
# 20	27	0.0	1	0 27
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S485_228_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S485_229_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S485_228_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S485_229_L001_R2_001.fastq.gz
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S485_228_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S485_229_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S485_228_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S485_229_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        56,760 reads  @     64.0 µs/read;   0.94 M reads/minute
# Finished in 3.64 s (64 us/read; 0.94 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             56,760
#   Read 1 with adapter:                  56,693 (99.9%)
#   Read 2 with adapter:                  56,476 (99.5%)
# Pairs written (passing filters):        56,760 (100.0%)
#
# Total basepairs processed:    33,484,588 bp
#   Read 1:    16,740,898 bp
#   Read 2:    16,743,690 bp
# Total written (filtered):     31,278,862 bp (93.4%)
#   Read 1:    15,607,545 bp
#   Read 2:    15,671,317 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 56693 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	28	0.0	1	0 0 28
# 19	581	0.0	1	0 550 31
# 20	55984	0.0	2	52955 2947 82
# 21	70	0.0	2	0 68 2
# 22	30	0.0	2	0 0 30
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 56476 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	759	0.0	1	0 759
# 19	55629	0.0	1	54204 1425
# 20	88	0.0	1	0 88
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S486_230_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S486_231_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S486_230_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S486_231_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S486_230_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S486_231_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S486_230_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S486_231_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        74,811 reads  @     66.8 µs/read;   0.90 M reads/minute
# Finished in 5.00 s (67 us/read; 0.90 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             74,811
#   Read 1 with adapter:                  74,442 (99.5%)
#   Read 2 with adapter:                  74,205 (99.2%)
# Pairs written (passing filters):        74,811 (100.0%)
#
# Total basepairs processed:    44,135,376 bp
#   Read 1:    22,067,800 bp
#   Read 2:    22,067,576 bp
# Total written (filtered):     41,238,078 bp (93.4%)
#   Read 1:    20,579,553 bp
#   Read 2:    20,658,525 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 74442 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	39	0.0	1	0 0 39
# 19	815	0.0	1	0 768 47
# 20	73390	0.0	2	68935 4335 120
# 21	96	0.0	2	0 93 3
# 22	102	0.0	2	0 0 102
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 74205 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	927	0.0	1	0 927
# 19	73195	0.0	1	70828 2367
# 20	83	0.0	1	0 83
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S487_232_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S487_233_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S487_232_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S487_233_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S487_232_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S487_233_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S487_232_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S487_233_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8<---------] 00:00:03        55,242 reads  @     67.0 µs/read;   0.90 M reads/minute
# Finished in 3.71 s (67 us/read; 0.89 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             55,242
#   Read 1 with adapter:                  55,176 (99.9%)
#   Read 2 with adapter:                  54,954 (99.5%)
# Pairs written (passing filters):        55,242 (100.0%)
#
# Total basepairs processed:    32,586,688 bp
#   Read 1:    16,290,917 bp
#   Read 2:    16,295,771 bp
# Total written (filtered):     30,439,964 bp (93.4%)
#   Read 1:    15,187,607 bp
#   Read 2:    15,252,357 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 55176 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	22	0.0	1	0 0 22
# 19	355	0.0	1	0 339 16
# 20	54651	0.0	2	51875 2709 67
# 21	107	0.0	2	0 107
# 22	41	0.0	2	0 0 41
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 54954 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	791	0.0	1	0 791
# 19	54084	0.0	1	52712 1372
# 20	79	0.0	1	0 79
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S488_234_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S488_235_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S488_234_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S488_235_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S488_234_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S488_235_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S488_234_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S488_235_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [ 8=---------] 00:00:04        66,067 reads  @     67.3 µs/read;   0.89 M reads/minute
# Finished in 4.45 s (67 us/read; 0.89 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             66,067
#   Read 1 with adapter:                  66,016 (99.9%)
#   Read 2 with adapter:                  65,602 (99.3%)
# Pairs written (passing filters):        66,066 (100.0%)
#
# Total basepairs processed:    38,956,896 bp
#   Read 1:    19,489,462 bp
#   Read 2:    19,467,434 bp
# Total written (filtered):     36,391,197 bp (93.4%)
#   Read 1:    18,169,260 bp
#   Read 2:    18,221,937 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 66016 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	33	0.0	1	0 0 33
# 19	579	0.0	1	0 542 37
# 20	65214	0.0	2	62059 3078 77
# 21	128	0.0	2	0 125 3
# 22	62	0.0	2	0 0 62
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 65602 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	1047	0.0	1	0 1047
# 19	64449	0.0	1	62839 1610
# 20	106	0.0	1	0 106
#
# Command: cutadapt --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S489_236_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S489_237_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S489_236_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S489_237_L001_R2_001.fastq.gz
#
# This is cutadapt 2.10 with Python 3.6.10
# Command line parameters: --cores 1 --error-rate 0.1 --times 1 --overlap 3 --minimum-length 1 -o /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S489_236_L001_R1_001.fastq.gz -p /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/q2-CasavaOneEightSingleLanePerSampleDirFmt-fc0viq0v/S489_237_L001_R2_001.fastq.gz --front ^AGGGCAAKYCTGGTGCCAGC -G ^GRCGGTATCTRATCGYCTT /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S489_236_L001_R1_001.fastq.gz /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-archive-an7qmcyt/1da33cfc-fdb2-45dd-8c70-3cf94959a4d6/data/S489_237_L001_R2_001.fastq.gz
# Processing reads on 1 core in paired-end mode ...
# [8<----------] 00:00:00        14,325 reads  @     67.5 µs/read;   0.89 M reads/minute
# Finished in 0.97 s (68 us/read; 0.89 M reads/minute).
#
# === Summary ===
#
# Total read pairs processed:             14,325
#   Read 1 with adapter:                  14,310 (99.9%)
#   Read 2 with adapter:                  14,268 (99.6%)
# Pairs written (passing filters):        14,325 (100.0%)
#
# Total basepairs processed:     8,451,705 bp
#   Read 1:     4,225,872 bp
#   Read 2:     4,225,833 bp
# Total written (filtered):      7,894,703 bp (93.4%)
#   Read 1:     3,939,729 bp
#   Read 2:     3,954,974 bp
#
# === First read: Adapter 1 ===
#
# Sequence: AGGGCAAKYCTGGTGCCAGC; Type: anchored 5'; Length: 20; Trimmed: 14310 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1; 20 bp: 2
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	2	0.0	1	0 0 2
# 19	121	0.0	1	0 116 5
# 20	14137	0.0	2	13497 628 12
# 21	32	0.0	2	0 31 1
# 22	18	0.0	2	0 0 18
#
#
# === Second read: Adapter 2 ===
#
# Sequence: GRCGGTATCTRATCGYCTT; Type: anchored 5'; Length: 19; Trimmed: 14268 times
#
# No. of allowed errors:
# 0-9 bp: 0; 10-19 bp: 1
#
# Overview of removed sequences
# length	count	expect	max.err	error counts
# 18	250	0.0	1	0 250
# 19	14001	0.0	1	13660 341
# 20	17	0.0	1	0 17
# Saved SampleData[PairedEndSequencesWithQuality] to: 18S-demux-pairedend-trimmed2.qza

# %%
# !qiime demux summarize \
  --i-data 18S-demux-pairedend-trimmed1.qza\
  --o-visualization 18S-demux-pairedend-trimmed1.qzv
# !qiime demux summarize \
  --i-data 18S-demux-pairedend-trimmed2.qza\
  --o-visualization 18S-demux-pairedend-trimmed2.qzv
# Out:
# Saved Visualization to: 18S-demux-pairedend-trimmed1.qzv
# Saved Visualization to: 18S-demux-pairedend-trimmed2.qzv

# %%
q2.Visualization.load('18S-demux-pairedend-trimmed1.qzv')
# Out:
# <visualization: Visualization uuid: 776cd39a-c0b4-4605-b7dc-a324bc1d0a28>

# %%
q2.Visualization.load('18S-demux-pairedend-trimmed2.qzv')
# Out:
# <visualization: Visualization uuid: a611e583-cab5-4093-8d93-65cbcdbbf1bc>

# %%
#Generate ESVs (Exact Sequence Variants). QIIME2 has two packages available for this. We are using dada2 for our single end reads.
# NOTE: if you are wanting to do paired end reads, you'll use qiime dada2 denoise-paired (https://docs.qiime2.org/2019.7/plugins/available/dada2/denoise-paired/)
# NOTE: if you are wanting to join reads you'll have to use Deblur


# !qiime dada2 denoise-paired \
  --i-demultiplexed-seqs 18S-demux-pairedend-trimmed1.qza \
  --p-trunc-len-f 273 \
  --p-trunc-len-r 216 \
  --p-pooling-method pseudo \
  --p-chimera-method consensus \
  --p-n-threads 0 \
  --p-n-reads-learn 10000 \
  --o-representative-sequences 18S-paired-end-demux_rep-seqs-dada2_r1.qza \
  --o-table 18S-paired-end-demux_table-dada2_r1.qza \
  --o-denoising-stats 18S-paired-end-demux_stats-dada2_r1.qza
# Out:
# Saved FeatureTable[Frequency] to: 18S-paired-end-demux_table-dada2_r1.qza
# Saved FeatureData[Sequence] to: 18S-paired-end-demux_rep-seqs-dada2_r1.qza
# Saved SampleData[DADA2Stats] to: 18S-paired-end-demux_stats-dada2_r1.qza

# %%
q2.Visualization.load('18S-demux-pairedend-trimmed2.qzv')
# Out:
# <visualization: Visualization uuid: a611e583-cab5-4093-8d93-65cbcdbbf1bc>

# %%
#Generate ESVs (Exact Sequence Variants). QIIME2 has two packages available for this. We are using dada2 for our single end reads.
# NOTE: if you are wanting to do paired end reads, you'll use qiime dada2 denoise-paired (https://docs.qiime2.org/2019.7/plugins/available/dada2/denoise-paired/)
# NOTE: if you are wanting to join reads you'll have to use Deblur


# !qiime dada2 denoise-paired \
  --i-demultiplexed-seqs 18S-demux-pairedend-trimmed2.qza \
  --p-trunc-len-f 273 \
  --p-trunc-len-r 213 \
  --p-pooling-method pseudo \
  --p-chimera-method consensus \
  --p-n-threads 0 \
  --p-n-reads-learn 10000 \
  --o-representative-sequences 18S-paired-end-demux_rep-seqs-dada2_r2.qza \
  --o-table 18S-paired-end-demux_table-dada2_r2.qza \
  --o-denoising-stats 18S-paired-end-demux_stats-dada2_r2.qza
# Out:
# Saved FeatureTable[Frequency] to: 18S-paired-end-demux_table-dada2_r2.qza
# Saved FeatureData[Sequence] to: 18S-paired-end-demux_rep-seqs-dada2_r2.qza
# Saved SampleData[DADA2Stats] to: 18S-paired-end-demux_stats-dada2_r2.qza

# %%
# The feature-table summarize command will give you information on how many sequences are associated with each sample and with each feature, histograms of those distributions, and some related summary statistics. 
# !qiime feature-table summarize \
  --i-table 18S-paired-end-demux_table-dada2_r1.qza \
  --o-visualization 18S-table_r1.qzv \
  #--m-sample-metadata-file metadata_18S_v3.txt
# The feature-table summarize command will give you information on how many sequences are associated with each sample and with each feature, histograms of those distributions, and some related summary statistics. 
# !qiime feature-table summarize \
  --i-table 18S-paired-end-demux_table-dada2_r2.qza \
  --o-visualization 18S-table_r2.qzv \
  #--m-sample-metadata-file metadata_18S_v3.txt
# Out:
# Saved Visualization to: 18S-table_r1.qzv
# Saved Visualization to: 18S-table_r2.qzv

# %%
#View the .qzv
q2.Visualization.load('18S-table_r1.qzv')
# Out:
# <visualization: Visualization uuid: c1d7899b-ab96-4313-8343-14e82e633326>

# %%
#View the .qzv
q2.Visualization.load('18S-table_r2.qzv')
# Out:
# <visualization: Visualization uuid: 234cbe72-3ff5-43d6-96f4-483e755639d3>

# %%
#now merge the two runs
# !qiime feature-table merge \
  --i-tables 18S-paired-end-demux_table-dada2_r1.qza \
  --i-tables 18S-paired-end-demux_table-dada2_r2.qza \
  --o-merged-table 18S-paired-end-demux_table-dada2.qza
# !qiime feature-table merge-seqs \
  --i-data 18S-paired-end-demux_rep-seqs-dada2_r1.qza  \
  --i-data 18S-paired-end-demux_rep-seqs-dada2_r2.qza  \
  --o-merged-data 18S-paired-end-demux_rep-seqs-dada2.qza
# Out:
# Saved FeatureTable[Frequency] to: 18S-paired-end-demux_table-dada2.qza
# Saved FeatureData[Sequence] to: 18S-paired-end-demux_rep-seqs-dada2.qza

# %%
# The feature-table summarize command will give you information on how many sequences are associated with each sample and with each feature, histograms of those distributions, and some related summary statistics. 
# !qiime feature-table summarize \
  --i-table 18S-paired-end-demux_table-dada2.qza \
  --o-visualization 18S-table.qzv \
 # --m-sample-metadata-file metadata_18S.txt
# Out:
# Saved Visualization to: 18S-table.qzv

# %%
#View the .qzv
q2.Visualization.load('18S-table.qzv')
# Out:
# <visualization: Visualization uuid: b4fee2af-0f0f-402b-8886-7dec5720efbb>

# %%
# !qiime feature-table tabulate-seqs \
  --i-data  18S-paired-end-demux_rep-seqs-dada2.qza \
  --o-visualization 18S-paired-end-demux_rep-seqs-dada2.qzv

#View the .qzv
q2.Visualization.load('18S-paired-end-demux_rep-seqs-dada2.qzv')
#download as fasta from visualized data
# Out:
# Saved Visualization to: 18S-paired-end-demux_rep-seqs-dada2.qzv
# <visualization: Visualization uuid: c367254f-93d5-4d6e-bbbb-3e036fafa7c8>

# %%
# !qiime tools export \
  --input-path 18S-paired-end-demux_table-dada2.qza \
  --output-path exported-feature-table
# Out:
# Exported 18S-paired-end-demux_table-dada2.qza as BIOMV210DirFmt to directory exported-feature-table

# %%
# !biom convert -i exported-feature-table/feature-table.biom -o 18S_ASVtable.tsv --to-tsv

# %%
# !biom convert -i exported-feature-table/feature-table.biom -o exported-feature-table/feature-table_hdf5.biom --to-hdf5 --table-type="OTU table"

# %%
# !biom convert -i exported-feature-table/feature-table.biom -o exported-feature-table/feature-table_json.biom --to-json --table-type="OTU table"

# %%
## classify with sklearn SILVA classifier

#!qiime feature-classifier classify-sklearn \
#  --i-classifier SILVA_132_99_nb_classifier.qza \
#  --i-reads 18S-paired-end-demux_rep-seqs-dada2.qza \
#  --o-classification 18SASV-rep-seqs-dada2_sklearnSILVA132_taxonomy.qza
#
#!qiime metadata tabulate \
#  --m-input-file 18SASV-rep-seqs-dada2_sklearnSILVA132_taxonomy.qza \
#  --o-visualization 18SASV-rep-seqs-dada2_sklearnSILVA132_taxonomy.qzv


## this doesn't work b/c the clasifier was trained using scikit-learn v 0.19.1 on the jcvi grid, and the local version of sklearn
#is 0.23.1. Transferring this fasta to the grid, importing to qiime, and classifying 
#the seqs using the version of sklearn that's installed there
# Out:
# Plugin error from feature-classifier:
#
#   The scikit-learn version (0.19.1) used to generate this artifact does not match the current version of scikit-learn installed (0.23.1). Please retrain your classifier for your current deployment to prevent data-corruption errors.
#
# Debug info has been saved to /var/folders/6q/fwkjrzpn4tnf1xgdkbr06_p80000gn/T/qiime2-q2cli-err-74lsabo7.log
# There was an issue with loading the file 18SASV-rep-seqs-dada2_sklearnSILVA132_taxonomy.qza as metadata:
#
#   Metadata file path doesn't exist, or the path points to something other than a file. Please check that the path exists, has read permissions, and points to a regular file (not a directory): 18SASV-rep-seqs-dada2_sklearnSILVA132_taxonomy.qza
#
#   There may be more errors present in the metadata file. To get a full report, sample/feature metadata files can be validated with Keemei: https://keemei.qiime2.org
#
#   Find details on QIIME 2 metadata requirements here: https://docs.qiime2.org/2020.6/tutorials/metadata/
